# %% [markdown]
# ### Importing necessary libraries ###

# %%
import os 
import time
import random

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder


from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, accuracy_score

import tqdm

import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import ConcatDataset
from torch.utils.data.dataset import random_split

# %% [markdown]
# ### Aranging Cuda Settings to get higher speed ###

# %%
# setting device as GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)

# CUDA device information
if device.type == 'cuda':
    print('GPU Name:', torch.cuda.get_device_name(0))
    print('Memory Stats:')
    print('  - Allocated:', round(torch.cuda.memory_allocated(0)/1024**3,1), 'GB')
    print('  - Cached:   ', round(torch.cuda.memory_reserved(0)/1024**3,1), 'GB')
    print('  - Total:    ', round(torch.cuda.get_device_properties(0).total_memory/1024**3,1), 'GB')
# Out:
# Using device: cuda
# GPU Name: NVIDIA GeForce RTX 2060
# Memory Stats:
#   - Allocated: 0.0 GB
#   - Cached:    0.0 GB
#   - Total:     6.0 GB

# %%
# transformation of images
transforming_img = transforms.Compose([
    transforms.Resize((150,150)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),  
    transforms.Normalize([0.5,0.5,0.5], 
                        [0.5,0.5,0.5])
])

# %%
# paths of train and test datasets
train_path = ('./brain_mri_dataset/Training/')
test_path = ('./brain_mri_dataset/Testing/')

# Gettings the datasets and combining them to shuffle all dataset and 
# to split it for extra dataset of validation
train_dataset=ImageFolder(train_path,transform=transforming_img)
test_dataset=ImageFolder(test_path,transform=transforming_img)
concated_dataset = ConcatDataset([train_dataset,test_dataset])

# %%
# aranging sizes of train, val, test datasets
train_size = int(0.8 * len(concated_dataset))
val_size = int(0.1 * len(concated_dataset))
test_size = len(concated_dataset) - (train_size + val_size)
len(concated_dataset),train_size, val_size, test_size
# Out:
# (3264, 2611, 326, 327)

# %%
#splitting the dataset
train_set, val_set, test_set= random_split(concated_dataset, [train_size, val_size,test_size])

# %% [markdown]
# #### Maybe some data visualizations...

# %% [markdown]
# ## Models

# %%
class CNN(nn.Module):
    def __init__(self,num_classes=4):
        super(CNN,self).__init__()
        self.conv1=nn.Conv2d(in_channels=3, out_channels=12, kernel_size=3, stride=1, padding=1)
        
        self.bn1=nn.BatchNorm2d(num_features=12)
        self.relu1=nn.ReLU()        
        self.pool=nn.MaxPool2d(kernel_size=2)
        self.conv2=nn.Conv2d(in_channels=12,out_channels=20,kernel_size=3,stride=1,padding=1)
        self.relu2=nn.ReLU()
        self.conv3=nn.Conv2d(in_channels=20,out_channels=32,kernel_size=3,stride=1,padding=1)
        self.bn3=nn.BatchNorm2d(num_features=32)
        self.relu3=nn.ReLU()
        self.fc=nn.Linear(in_features=75 * 75 * 32,out_features=num_classes)
        
        #Feed forwad function
    def forward(self,input):
        output=self.conv1(input)
        output=self.bn1(output)
        output=self.relu1(output)
        output=self.pool(output)
        output=self.conv2(output)
        output=self.relu2(output)
        output=self.conv3(output)
        output=self.bn3(output)
        output=self.relu3(output)            
        output=output.view(-1,32*75*75)
        output=self.fc(output)
            
        return output
CNN_model = CNN()

# %%
# Resnet pre-trained model
model_resnet_pretrained=models.resnet18(pretrained=True)
for param in model_resnet_pretrained.parameters():
    param.requires_grad = False
# Getting features
features=model_resnet_pretrained.fc.in_features
# Adding linear layer to classify 4 classes
model_resnet_pretrained.fc=nn.Linear(features,4)
# Out:
# C:\Users\ata_h\anaconda3\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\ata_h\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_resnet_not_pretrained=models.resnet18(pretrained=False)
for param in model_resnet_not_pretrained.parameters():
    param.requires_grad = False
# Getting features
features=model_resnet_not_pretrained.fc.in_features
# Adding linear layer to classify 4 classes
model_resnet_not_pretrained.fc=nn.Linear(features,4)
# Out:
# C:\Users\ata_h\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
model_efficientnet_b0_pretrained = models.efficientnet_b0(pretrained=True)

for param in model_efficientnet_b0_pretrained.parameters():
    param.requires_grad = False
    
num_inputs = model_efficientnet_b0_pretrained.classifier[1].in_features
model_efficientnet_b0_pretrained.classifier = nn.Sequential(nn.Linear(num_inputs, 4))
# Out:
# C:\Users\ata_h\anaconda3\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model_efficientnet_b0_not_pretrained = models.efficientnet_b0(pretrained=True)

for param in model_efficientnet_b0_not_pretrained.parameters():
    param.requires_grad = False

num_inputs = model_efficientnet_b0_not_pretrained.classifier[1].in_features
model_efficientnet_b0_not_pretrained.classifier = nn.Sequential(nn.Linear(num_inputs, 4))

# %% [markdown]
# ## Train, inference and test functions ##

# %%
def inference (model, val_set, val_batch):
    # passing model to device to use GPU
    model = model.to(device)
    # Loading the data
    val_loader = DataLoader(val_set, batch_size=val_batch, shuffle=True)
    # Defining loss function(criterion)
    criterion = nn.CrossEntropyLoss()
    
    true_prediction = 0
    total_predictions = 0
    running_loss = 0
    
    # Disabling gradient updates for inference process
    with torch.no_grad():
        for i, (images, labels) in enumerate(val_loader):
            # Get the input features and target labels, and put them on the GPU
            inputs=images.to(device)
            labels = labels.to(device)
            # Get predictions
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            # Get the predicted class with the highest score
            _, prediction = torch.max(outputs,1)
            # Count of predictions that matched the target label
            true_prediction += (prediction == labels).sum().item()
            total_predictions += prediction.shape[0]

        batch_number = len(val_loader)
        avg_loss = running_loss / batch_number
        accuracy = true_prediction/total_predictions
        return avg_loss, accuracy

# %%
def train(model,train_set,val_set,max_epoch,train_batch,val_batch,learning_rate,momentum,weight_decay):
    # passing model to device to use GPU
    model = model.to(device) 
    # Loading the data
    train_loader = DataLoader(train_set, batch_size=train_batch, shuffle=True)
    # Defining loss function(criterion) and optimizer with parameters
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=weight_decay)
    # Creating lists to store data from the training process
    Train_loss_list = []
    Val_loss_list = []
    Train_acc_list = []
    Val_acc_list = []
    n = len(train_loader)
    
    for epoch in range(max_epoch):
        true_prediction = 0
        total_predictions = 0  
        running_loss=0
        running_acc = 0
        with tqdm.tqdm(total= n, desc=f"Epoch {epoch+1}") as pbar:
            for i, (images, labels) in enumerate(train_loader):
                # passing inputs to device to use GPU
                images = images.to(device)
                labels = labels.to(device)     

                # Forward pass
                outputs = model(images)
                loss = criterion(outputs, labels)

                # Backward and optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                

                # Get the predicted class with the highest score
                _, prediction = torch.max(outputs,1) # no need for first return
                # Count of predictions that matched the target label
                true_prediction += (prediction == labels).sum().item()
                total_predictions += prediction.shape[0]
                # update acc
                running_acc = true_prediction/total_predictions
                
                # Update progress bar
                pbar.update(1)
                pbar.set_postfix(train_loss=loss.item(),train_acc=running_acc)
                running_loss += loss.item()
                
        batch_number = len(train_loader)
        avg_loss = running_loss / batch_number
        train_acc = true_prediction/total_predictions
        val_loss, val_acc = inference(model, val_set, val_batch)    
        Train_loss_list.append(avg_loss)
        Val_loss_list.append(val_loss)
        Val_acc_list.append(val_acc)
        Train_acc_list.append(train_acc)
    return Train_loss_list, Val_loss_list, Val_acc_list, Train_acc_list

# %%
def plot(train_param, val_param, metric):
    plt.figure(figsize = (12,6))
    plt.plot(train_param, label="Training set")
    plt.plot(val_param, label="Validation set")
    plt.xlabel("Epoch")
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# %%
def test(model,test_set):
    
    # passing model to device to use CPU
    model = model.to('cpu') 
    
    # Loading the data
    test_loader = DataLoader(test_set, batch_size=test_batch, shuffle=True)
    
    # Defining loss function(criterion) and optimizer with parameters
    criterion = nn.CrossEntropyLoss()

    correct_prediction = 0
    total_prediction = 0
    running_loss = 0
    
    # Creating lists to store data from the training process
    cm_list=[]
    f_score_list=[]
    p_score_list=[]
    r_score_list=[]
    test_acc_list=[]
    
    # Disable gradient updates
    with torch.no_grad():
        for i, (images, labels) in enumerate(test_loader):
                        
            # Get the input features and target labels, and put them on the GPU
            inputs=images.to('cpu')
            labels = labels.to('cpu')
            
            
            # Get predictions
            model = model.to('cpu')
            outputs = model(inputs).to('cpu')

            loss = criterion(outputs, labels)
            running_loss += loss.item()

            # Get the predicted class with the highest score
            _, prediction = torch.max(outputs,1)

            # Count of predictions that matched the target label
            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]

            f1 = f1_score(labels, prediction, average='macro', zero_division=1)
            precision=precision_score(labels, prediction, average='macro', zero_division=1)
            recall=recall_score(labels, prediction, average='macro', zero_division=1)
            cm = confusion_matrix(labels,prediction)
            accuracy = correct_prediction/total_prediction

            cm_list.append(cm)
            f_score_list.append(f1)
            p_score_list.append(precision)
            r_score_list.append(recall)
            test_acc_list.append(accuracy)
    return test_acc_list, f_score_list, p_score_list, r_score_list, cm_list

# %%
def report_test(test_acc_list, f_score_list, p_score_list, r_score_list, cm_list):
    print(f"Test accuracy is {sum(test_acc_list)/len(test_acc_list)}") # Note that these are average scores
    print(f"F score is {sum(f_score_list)/len(f_score_list)}")
    print(f"Precision is {sum(p_score_list)/len(p_score_list)}")
    print(f"Recall is {sum(r_score_list)/len(r_score_list)}")
    print(f"Confusion matrix is below \n {sns.heatmap(sum(cm_list), annot=True)}") #

# %% [markdown]
# ### Save and load model functions ###

# %%
def save_model(model, filepath): # saving the evaluated model
    # Save the model to a file
    torch.save(model, filepath)
    # Save the model's weights and biases
    torch.save(model.state_dict(), filepath + '_weights.pt')

# %%
def load_model(filepath): # loading the model if necessary
    # Load the saved model
    model = torch.load(filepath)
    # Load the saved weights and biases
    model.load_state_dict(torch.load(filepath + '_weights.pt'))
    return model

# %% [markdown]
# ## Now, we can train & test our models

# %%
# First lets give the hyperparameters
max_epoch = 60
train_batch = 64
val_batch = 64
test_batch = 64
learning_rate = 1e-2
momentum = 0.7
weight_decay = 5e-04

# %% [markdown]
# # Training CNN model

# %%
Train_loss_list, Val_loss_list, Val_acc_list, Train_acc_list = train(CNN_model,train_set,val_set,max_epoch,train_batch,val_batch,learning_rate,momentum,weight_decay)
# Out:
# Epoch 1: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  2.93it/s, train_acc=0.373, train_loss=1.15]
# Epoch 2: 100%|███████████████████████████████████████| 41/41 [00:11<00:00,  3.67it/s, train_acc=0.569, train_loss=1.11]
# Epoch 3: 100%|███████████████████████████████████████| 41/41 [00:11<00:00,  3.62it/s, train_acc=0.621, train_loss=0.71]
# Epoch 4: 100%|██████████████████████████████████████| 41/41 [00:11<00:00,  3.62it/s, train_acc=0.678, train_loss=0.829]
# Epoch 5: 100%|██████████████████████████████████████| 41/41 [00:11<00:00,  3.67it/s, train_acc=0.715, train_loss=0.664]
# Epoch 6: 100%|██████████████████████████████████████| 41/41 [00:11<00:00,  3.57it/s, train_acc=0.722, train_loss=0.833]
# Epoch 7: 100%|███████████████████████████████████████| 41/41 [00:11<00:00,  3.62it/s, train_acc=0.753, train_loss=0.67]
# Epoch 8: 100%|██████████████████████████████████████| 41/41 [00:11<00:00,  3.60it/s, train_acc=0.755, train_loss=0.521]
# Epoch 9: 100%|██████████████████████████████████████| 41/41 [00:11<00:00,  3.64it/s, train_acc=0.768, train_loss=0.495]
# Epoch 10: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.51it/s, train_acc=0.798, train_loss=0.509]
# Epoch 11: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.66it/s, train_acc=0.799, train_loss=0.634]
# Epoch 12: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.51it/s, train_acc=0.823, train_loss=0.579]
# Epoch 13: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.44it/s, train_acc=0.831, train_loss=0.526]
# Epoch 14: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.45it/s, train_acc=0.842, train_loss=0.458]
# Epoch 15: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.41it/s, train_acc=0.845, train_loss=0.35]
# Epoch 16: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.47it/s, train_acc=0.853, train_loss=0.652]
# Epoch 17: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.39it/s, train_acc=0.851, train_loss=0.481]
# Epoch 18: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.46it/s, train_acc=0.845, train_loss=0.355]
# Epoch 19: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.42it/s, train_acc=0.863, train_loss=0.319]
# Epoch 20: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.40it/s, train_acc=0.886, train_loss=0.273]
# Epoch 21: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.29it/s, train_acc=0.882, train_loss=0.435]
# Epoch 22: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.33it/s, train_acc=0.888, train_loss=0.307]
# Epoch 23: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.41it/s, train_acc=0.88, train_loss=0.187]
# Epoch 24: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.45it/s, train_acc=0.887, train_loss=0.203]
# Epoch 25: 100%|███████████████████████████████████████| 41/41 [00:12<00:00,  3.33it/s, train_acc=0.9, train_loss=0.209]
# Epoch 26: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.34it/s, train_acc=0.904, train_loss=0.211]
# Epoch 27: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.37it/s, train_acc=0.915, train_loss=0.17]
# Epoch 28: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.35it/s, train_acc=0.913, train_loss=0.152]
# Epoch 29: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.35it/s, train_acc=0.925, train_loss=0.23]
# Epoch 30: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.35it/s, train_acc=0.924, train_loss=0.147]
# Epoch 31: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.36it/s, train_acc=0.924, train_loss=0.161]
# Epoch 32: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.38it/s, train_acc=0.923, train_loss=0.204]
# Epoch 33: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.41it/s, train_acc=0.929, train_loss=0.165]
# Epoch 34: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.36it/s, train_acc=0.934, train_loss=0.201]
# Epoch 35: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.38it/s, train_acc=0.947, train_loss=0.123]
# Epoch 36: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.31it/s, train_acc=0.95, train_loss=0.217]
# Epoch 37: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.34it/s, train_acc=0.956, train_loss=0.115]
# Epoch 38: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.32it/s, train_acc=0.953, train_loss=0.0714]
# Epoch 39: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.25it/s, train_acc=0.963, train_loss=0.104]
# Epoch 40: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.27it/s, train_acc=0.964, train_loss=0.0877]
# Epoch 41: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.22it/s, train_acc=0.946, train_loss=0.431]
# Epoch 42: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.28it/s, train_acc=0.962, train_loss=0.108]
# Epoch 43: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.35it/s, train_acc=0.96, train_loss=0.0669]
# Epoch 44: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.37it/s, train_acc=0.965, train_loss=0.117]
# Epoch 45: 100%|█████████████████████████████████████| 41/41 [00:11<00:00,  3.42it/s, train_acc=0.962, train_loss=0.105]
# Epoch 46: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.35it/s, train_acc=0.964, train_loss=0.0226]
# Epoch 47: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.40it/s, train_acc=0.98, train_loss=0.147]
# Epoch 48: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.33it/s, train_acc=0.966, train_loss=0.0452]
# Epoch 49: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.37it/s, train_acc=0.975, train_loss=0.0603]
# Epoch 50: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.31it/s, train_acc=0.98, train_loss=0.0577]
# Epoch 51: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.24it/s, train_acc=0.976, train_loss=0.0515]
# Epoch 52: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.31it/s, train_acc=0.978, train_loss=0.0294]
# Epoch 53: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.32it/s, train_acc=0.991, train_loss=0.072]
# Epoch 54: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.24it/s, train_acc=0.985, train_loss=0.0322]
# Epoch 55: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.30it/s, train_acc=0.979, train_loss=0.0207]
# Epoch 56: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.31it/s, train_acc=0.984, train_loss=0.0299]
# Epoch 57: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.33it/s, train_acc=0.978, train_loss=0.155]
# Epoch 58: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.36it/s, train_acc=0.987, train_loss=0.0176]
# Epoch 59: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.28it/s, train_acc=0.986, train_loss=0.0175]
# Epoch 60: 100%|████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.986, train_loss=0.0267]

# %% [markdown]
# ## Plotting the training and validation results ##

# %%
plot(Train_acc_list,Val_acc_list,"Accuracy")
plot(Train_loss_list,Val_loss_list,"Loss")

# %% [markdown]
# ## Test Results ##

# %%
test_acc_list, f_score_list, p_score_list, r_score_list, cm_list = test(CNN_model,test_set)
report_test(test_acc_list, f_score_list, p_score_list, r_score_list, cm_list)
# Out:
# Test accuracy is 0.822205498216106
# F score is 0.8154819461841765
# Precision is 0.8513958460843135
# Recall is 0.8252142078300545
# Confusion matrix is below
#  AxesSubplot(0.125,0.11;0.62x0.77)

# %% [markdown]
#  # Training & Testing pre trained ResNet model

# %%
Train_loss_list1, Val_loss_list1, Val_acc_list1, Train_acc_list1 = train(model_resnet_pretrained,train_set,val_set,max_epoch,train_batch,val_batch,learning_rate,momentum,weight_decay)
# Out:
# Epoch 1: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.634, train_loss=0.581]
# Epoch 2: 100%|███████████████████████████████████████| 41/41 [00:12<00:00,  3.20it/s, train_acc=0.771, train_loss=0.67]
# Epoch 3: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.20it/s, train_acc=0.804, train_loss=0.495]
# Epoch 4: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.24it/s, train_acc=0.819, train_loss=0.381]
# Epoch 5: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.825, train_loss=0.352]
# Epoch 6: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.24it/s, train_acc=0.839, train_loss=0.412]
# Epoch 7: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.848, train_loss=0.367]
# Epoch 8: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.21it/s, train_acc=0.846, train_loss=0.358]
# Epoch 9: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.851, train_loss=0.356]
# Epoch 10: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.853, train_loss=0.33]
# Epoch 11: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.25it/s, train_acc=0.844, train_loss=0.268]
# Epoch 12: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.851, train_loss=0.547]
# Epoch 13: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.86, train_loss=0.266]
# Epoch 14: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.861, train_loss=0.236]
# Epoch 15: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.852, train_loss=0.412]
# Epoch 16: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.858, train_loss=0.395]
# Epoch 17: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.859, train_loss=0.43]
# Epoch 18: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.853, train_loss=0.293]
# Epoch 19: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.867, train_loss=0.53]
# Epoch 20: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.872, train_loss=0.233]
# Epoch 21: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.883, train_loss=0.393]
# Epoch 22: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.875, train_loss=0.31]
# Epoch 23: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.88, train_loss=0.407]
# Epoch 24: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.879, train_loss=0.352]
# Epoch 25: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.878, train_loss=0.438]
# Epoch 26: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.877, train_loss=0.283]
# Epoch 27: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.873, train_loss=0.418]
# Epoch 28: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.884, train_loss=0.393]
# Epoch 29: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.864, train_loss=0.2]
# Epoch 30: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.88, train_loss=0.32]
# Epoch 31: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.874, train_loss=0.601]
# Epoch 32: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.865, train_loss=0.426]
# Epoch 33: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.889, train_loss=0.382]
# Epoch 34: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.879, train_loss=0.527]
# Epoch 35: 100%|█████████████████████████████████████| 41/41 [00:14<00:00,  2.90it/s, train_acc=0.879, train_loss=0.223]
# Epoch 36: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  2.95it/s, train_acc=0.88, train_loss=0.37]
# Epoch 37: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.89, train_loss=0.293]
# Epoch 38: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.879, train_loss=0.26]
# Epoch 39: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.87, train_loss=0.36]
# Epoch 40: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.894, train_loss=0.376]
# Epoch 41: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.882, train_loss=0.416]
# Epoch 42: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.884, train_loss=0.379]
# Epoch 43: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.869, train_loss=0.302]
# Epoch 44: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.878, train_loss=0.472]
# Epoch 45: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.887, train_loss=0.389]
# Epoch 46: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.881, train_loss=0.231]
# Epoch 47: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.899, train_loss=0.313]
# Epoch 48: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.892, train_loss=0.29]
# Epoch 49: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.887, train_loss=0.346]
# Epoch 50: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.884, train_loss=0.164]
# Epoch 51: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.881, train_loss=0.534]
# Epoch 52: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.872, train_loss=0.211]
# Epoch 53: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.882, train_loss=0.496]
# Epoch 54: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.887, train_loss=0.301]
# Epoch 55: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.879, train_loss=0.296]
# Epoch 56: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.894, train_loss=0.278]
# Epoch 57: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.885, train_loss=0.501]
# Epoch 58: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.902, train_loss=0.176]
# Epoch 59: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.9, train_loss=0.185]
# Epoch 60: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.05it/s, train_acc=0.896, train_loss=0.381]

# %%
plot(Train_acc_list1,Val_acc_list1,"Accuracy")
plot(Train_loss_list1,Val_loss_list1,"Loss")

# %%
test_acc_list1, f_score_list1, p_score_list1, r_score_list1, cm_list1 = test(model_resnet_pretrained,test_set)
report_test(test_acc_list1, f_score_list1, p_score_list1, r_score_list1, cm_list1)
# Out:
# Test accuracy is 0.8160012901376148
# F score is 0.8015910746277731
# Precision is 0.8303578869994689
# Recall is 0.8104171551901732
# Confusion matrix is below
#  AxesSubplot(0.125,0.11;0.62x0.77)

# %% [markdown]
#  # Training & Testing pre trained EffNet model

# %%
Train_loss_list2, Val_loss_list2, Val_acc_list2, Train_acc_list2 = train(model_efficientnet_b0_pretrained,train_set,val_set,max_epoch,train_batch,val_batch,learning_rate,momentum,weight_decay)
# Out:
# Epoch 1: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.625, train_loss=0.715]
# Epoch 2: 100%|████████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.761, train_loss=0.6]
# Epoch 3: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.24it/s, train_acc=0.795, train_loss=0.718]
# Epoch 4: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.20it/s, train_acc=0.805, train_loss=0.612]
# Epoch 5: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.21it/s, train_acc=0.818, train_loss=0.661]
# Epoch 6: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.817, train_loss=0.548]
# Epoch 7: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.20it/s, train_acc=0.829, train_loss=0.587]
# Epoch 8: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.822, train_loss=0.388]
# Epoch 9: 100%|███████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.837, train_loss=0.43]
# Epoch 10: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.842, train_loss=0.481]
# Epoch 11: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.851, train_loss=0.696]
# Epoch 12: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.854, train_loss=0.514]
# Epoch 13: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.852, train_loss=0.599]
# Epoch 14: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.862, train_loss=0.377]
# Epoch 15: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  2.98it/s, train_acc=0.853, train_loss=0.331]
# Epoch 16: 100%|█████████████████████████████████████| 41/41 [00:14<00:00,  2.86it/s, train_acc=0.858, train_loss=0.339]
# Epoch 17: 100%|█████████████████████████████████████| 41/41 [00:14<00:00,  2.92it/s, train_acc=0.859, train_loss=0.386]
# Epoch 18: 100%|█████████████████████████████████████| 41/41 [00:14<00:00,  2.75it/s, train_acc=0.874, train_loss=0.361]
# Epoch 19: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.869, train_loss=0.407]
# Epoch 20: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.861, train_loss=0.398]
# Epoch 21: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.871, train_loss=0.394]
# Epoch 22: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.867, train_loss=0.423]
# Epoch 23: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.871, train_loss=0.411]
# Epoch 24: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.878, train_loss=0.414]
# Epoch 25: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.877, train_loss=0.411]
# Epoch 26: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.881, train_loss=0.405]
# Epoch 27: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.882, train_loss=0.401]
# Epoch 28: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.874, train_loss=0.284]
# Epoch 29: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.878, train_loss=0.38]
# Epoch 30: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.879, train_loss=0.281]
# Epoch 31: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.886, train_loss=0.239]
# Epoch 32: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.05it/s, train_acc=0.877, train_loss=0.357]
# Epoch 33: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.875, train_loss=0.486]
# Epoch 34: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  2.98it/s, train_acc=0.885, train_loss=0.261]
# Epoch 35: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.887, train_loss=0.369]
# Epoch 36: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.887, train_loss=0.266]
# Epoch 37: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.26it/s, train_acc=0.887, train_loss=0.277]
# Epoch 38: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.886, train_loss=0.344]
# Epoch 39: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.27it/s, train_acc=0.889, train_loss=0.362]
# Epoch 40: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.23it/s, train_acc=0.882, train_loss=0.255]
# Epoch 41: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.01it/s, train_acc=0.888, train_loss=0.312]
# Epoch 42: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.879, train_loss=0.324]
# Epoch 43: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.882, train_loss=0.437]
# Epoch 44: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.896, train_loss=0.396]
# Epoch 45: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.888, train_loss=0.33]
# Epoch 46: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.895, train_loss=0.334]
# Epoch 47: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.897, train_loss=0.288]
# Epoch 48: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.888, train_loss=0.284]
# Epoch 49: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.885, train_loss=0.469]
# Epoch 50: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.899, train_loss=0.398]
# Epoch 51: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.894, train_loss=0.285]
# Epoch 52: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.89, train_loss=0.303]
# Epoch 53: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.9, train_loss=0.263]
# Epoch 54: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.894, train_loss=0.204]
# Epoch 55: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.9, train_loss=0.292]
# Epoch 56: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.902, train_loss=0.329]
# Epoch 57: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.897, train_loss=0.334]
# Epoch 58: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.896, train_loss=0.216]
# Epoch 59: 100%|████████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.9, train_loss=0.27]
# Epoch 60: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.903, train_loss=0.304]

# %%
plot(Train_acc_list2,Val_acc_list2,"Accuracy")
plot(Train_loss_list2,Val_loss_list2,"Loss")

# %%
test_acc_list2, f_score_list2, p_score_list2, r_score_list2, cm_list2 = test(model_efficientnet_b0_pretrained,test_set)
report_test(test_acc_list2, f_score_list2, p_score_list2, r_score_list2, cm_list2)
# Out:
# Test accuracy is 0.8576086264016309
# F score is 0.8467898246188145
# Precision is 0.8480800053990843
# Recall is 0.858481506919007
# Confusion matrix is below
#  AxesSubplot(0.125,0.11;0.62x0.77)

# %% [markdown]
#  # Training & Testing not pre trained ResNet model

# %%
Train_loss_list3, Val_loss_list3, Val_acc_list3, Train_acc_list3 = train(model_resnet_not_pretrained,train_set,val_set,max_epoch,train_batch,val_batch,learning_rate,momentum,weight_decay)
# Out:
# Epoch 1: 100%|███████████████████████████████████████| 41/41 [00:14<00:00,  2.83it/s, train_acc=0.357, train_loss=1.25]
# Epoch 2: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.459, train_loss=1.14]
# Epoch 3: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.474, train_loss=1.19]
# Epoch 4: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.525, train_loss=1.09]
# Epoch 5: 100%|███████████████████████████████████████| 41/41 [00:12<00:00,  3.21it/s, train_acc=0.537, train_loss=1.14]
# Epoch 6: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.548, train_loss=1.03]
# Epoch 7: 100%|███████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.578, train_loss=0.97]
# Epoch 8: 100%|███████████████████████████████████████| 41/41 [00:12<00:00,  3.20it/s, train_acc=0.564, train_loss=1.02]
# Epoch 9: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.581, train_loss=0.933]
# Epoch 10: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.586, train_loss=0.941]
# Epoch 11: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.589, train_loss=0.884]
# Epoch 12: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.23it/s, train_acc=0.594, train_loss=1.17]
# Epoch 13: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.594, train_loss=1.13]
# Epoch 14: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.6, train_loss=0.999]
# Epoch 15: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.593, train_loss=1.01]
# Epoch 16: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.616, train_loss=0.891]
# Epoch 17: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.22it/s, train_acc=0.615, train_loss=0.916]
# Epoch 18: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.15it/s, train_acc=0.588, train_loss=0.847]
# Epoch 19: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.611, train_loss=0.912]
# Epoch 20: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.617, train_loss=0.847]
# Epoch 21: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.615, train_loss=0.809]
# Epoch 22: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.617, train_loss=1.01]
# Epoch 23: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.15it/s, train_acc=0.633, train_loss=0.77]
# Epoch 24: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.63, train_loss=0.823]
# Epoch 25: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.629, train_loss=1.01]
# Epoch 26: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.608, train_loss=0.964]
# Epoch 27: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.638, train_loss=0.825]
# Epoch 28: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.61, train_loss=0.724]
# Epoch 29: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.03it/s, train_acc=0.622, train_loss=0.874]
# Epoch 30: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.627, train_loss=0.973]
# Epoch 31: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.63, train_loss=0.935]
# Epoch 32: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.638, train_loss=0.849]
# Epoch 33: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.643, train_loss=1.03]
# Epoch 34: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.638, train_loss=0.88]
# Epoch 35: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.642, train_loss=0.846]
# Epoch 36: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.647, train_loss=0.75]
# Epoch 37: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.626, train_loss=1.06]
# Epoch 38: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.653, train_loss=0.958]
# Epoch 39: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.651, train_loss=0.882]
# Epoch 40: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.643, train_loss=0.827]
# Epoch 41: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.644, train_loss=0.905]
# Epoch 42: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.645, train_loss=0.81]
# Epoch 43: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.15it/s, train_acc=0.657, train_loss=0.791]
# Epoch 44: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.655, train_loss=1.18]
# Epoch 45: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.19it/s, train_acc=0.652, train_loss=0.853]
# Epoch 46: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.661, train_loss=1.15]
# Epoch 47: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.665, train_loss=0.77]
# Epoch 48: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.667, train_loss=0.74]
# Epoch 49: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.653, train_loss=1.02]
# Epoch 50: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.657, train_loss=0.75]
# Epoch 51: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.665, train_loss=0.911]
# Epoch 52: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.18it/s, train_acc=0.669, train_loss=0.902]
# Epoch 53: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.05it/s, train_acc=0.654, train_loss=0.903]
# Epoch 54: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.659, train_loss=0.919]
# Epoch 55: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.679, train_loss=0.777]
# Epoch 56: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.66, train_loss=0.913]
# Epoch 57: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.672, train_loss=0.822]
# Epoch 58: 100%|█████████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.669, train_loss=1]
# Epoch 59: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.21it/s, train_acc=0.673, train_loss=0.725]
# Epoch 60: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.674, train_loss=0.983]

# %%
plot(Train_acc_list3,Val_acc_list3,"Accuracy")
plot(Train_loss_list3,Val_loss_list3,"Loss")

# %%
test_acc_list3, f_score_list3, p_score_list3, r_score_list3, cm_list3 = test(model_resnet_not_pretrained,test_set)
report_test(test_acc_list3, f_score_list3, p_score_list3, r_score_list3, cm_list3)
# Out:
# Test accuracy is 0.6655481492099898
# F score is 0.6358899045667287
# Precision is 0.6917321336071337
# Recall is 0.6304073782189528
# Confusion matrix is below
#  AxesSubplot(0.125,0.11;0.62x0.77)

# %% [markdown]
#  # Training & Testing not pre trained EffNet model

# %%
Train_loss_list4, Val_loss_list4, Val_acc_list4, Train_acc_list4 = train(model_efficientnet_b0_not_pretrained,train_set,val_set,max_epoch,train_batch,val_batch,learning_rate,momentum,weight_decay)
# Out:
# Epoch 1: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.605, train_loss=0.791]
# Epoch 2: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.764, train_loss=0.631]
# Epoch 3: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.784, train_loss=0.637]
# Epoch 4: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.807, train_loss=0.638]
# Epoch 5: 100%|████████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.81, train_loss=0.63]
# Epoch 6: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.823, train_loss=0.749]
# Epoch 7: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.829, train_loss=0.462]
# Epoch 8: 100%|███████████████████████████████████████| 41/41 [00:12<00:00,  3.17it/s, train_acc=0.83, train_loss=0.482]
# Epoch 9: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.15it/s, train_acc=0.84, train_loss=0.384]
# Epoch 10: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.844, train_loss=0.474]
# Epoch 11: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.853, train_loss=0.477]
# Epoch 12: 100%|██████████████████████████████████████| 41/41 [00:12<00:00,  3.16it/s, train_acc=0.854, train_loss=0.42]
# Epoch 13: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.13it/s, train_acc=0.85, train_loss=0.445]
# Epoch 14: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.855, train_loss=0.553]
# Epoch 15: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.863, train_loss=0.393]
# Epoch 16: 100%|█████████████████████████████████████| 41/41 [00:12<00:00,  3.15it/s, train_acc=0.864, train_loss=0.423]
# Epoch 17: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.864, train_loss=0.42]
# Epoch 18: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.859, train_loss=0.401]
# Epoch 19: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  2.96it/s, train_acc=0.862, train_loss=0.371]
# Epoch 20: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.858, train_loss=0.503]
# Epoch 21: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.867, train_loss=0.476]
# Epoch 22: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.865, train_loss=0.503]
# Epoch 23: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.874, train_loss=0.408]
# Epoch 24: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.874, train_loss=0.244]
# Epoch 25: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.878, train_loss=0.364]
# Epoch 26: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.10it/s, train_acc=0.876, train_loss=0.415]
# Epoch 27: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.04it/s, train_acc=0.872, train_loss=0.249]
# Epoch 28: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.882, train_loss=0.399]
# Epoch 29: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  2.99it/s, train_acc=0.872, train_loss=0.356]
# Epoch 30: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.885, train_loss=0.39]
# Epoch 31: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.879, train_loss=0.239]
# Epoch 32: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.896, train_loss=0.584]
# Epoch 33: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.887, train_loss=0.294]
# Epoch 34: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.882, train_loss=0.341]
# Epoch 35: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.05it/s, train_acc=0.887, train_loss=0.264]
# Epoch 36: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.887, train_loss=0.329]
# Epoch 37: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.886, train_loss=0.434]
# Epoch 38: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.892, train_loss=0.218]
# Epoch 39: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.12it/s, train_acc=0.891, train_loss=0.434]
# Epoch 40: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.895, train_loss=0.286]
# Epoch 41: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.9, train_loss=0.316]
# Epoch 42: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.891, train_loss=0.283]
# Epoch 43: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.885, train_loss=0.456]
# Epoch 44: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.11it/s, train_acc=0.889, train_loss=0.337]
# Epoch 45: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.903, train_loss=0.304]
# Epoch 46: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.02it/s, train_acc=0.894, train_loss=0.3]
# Epoch 47: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.892, train_loss=0.216]
# Epoch 48: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.899, train_loss=0.341]
# Epoch 49: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.907, train_loss=0.398]
# Epoch 50: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.05it/s, train_acc=0.887, train_loss=0.291]
# Epoch 51: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.09it/s, train_acc=0.892, train_loss=0.204]
# Epoch 52: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.06it/s, train_acc=0.888, train_loss=0.288]
# Epoch 53: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.892, train_loss=0.246]
# Epoch 54: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.892, train_loss=0.279]
# Epoch 55: 100%|██████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.897, train_loss=0.36]
# Epoch 56: 100%|███████████████████████████████████████| 41/41 [00:13<00:00,  3.07it/s, train_acc=0.9, train_loss=0.388]
# Epoch 57: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.08it/s, train_acc=0.897, train_loss=0.248]
# Epoch 58: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.02it/s, train_acc=0.894, train_loss=0.318]
# Epoch 59: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.14it/s, train_acc=0.907, train_loss=0.341]
# Epoch 60: 100%|█████████████████████████████████████| 41/41 [00:13<00:00,  3.04it/s, train_acc=0.913, train_loss=0.429]

# %%
plot(Train_acc_list4,Val_acc_list4,"Accuracy")
plot(Train_loss_list4,Val_loss_list4,"Loss")

# %%
test_acc_list4, f_score_list4, p_score_list4, r_score_list4, cm_list4 = test(model_efficientnet_b0_not_pretrained,test_set)
report_test(test_acc_list4, f_score_list4, p_score_list4, r_score_list4, cm_list4)
# Out:
# Test accuracy is 0.8914615984964321
# F score is 0.8334189692147693
# Precision is 0.8742983284488702
# Recall is 0.8573387121993933
# Confusion matrix is below
#  AxesSubplot(0.125,0.11;0.62x0.77)
